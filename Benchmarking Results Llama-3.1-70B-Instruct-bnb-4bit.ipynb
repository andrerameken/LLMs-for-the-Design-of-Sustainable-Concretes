# %%
import pandas as pd
import numpy as np
from scipy import stats
import os
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from IPython.display import Markdown, display
from utils import gather_metric_results, create_markdown_table, plot_actual_vs_predicted


model_name = "Llama-3.1-70B-Instruct-bnb-4bit"
approaches = ["RF", "GPR", "ICL_finetuned", "ICL"]

metric_results = gather_metric_results(approaches, model_name)
create_markdown_table(metric_results)
plot_actual_vs_predicted(model_name)
# Out:
# ## Benchmarking Results
# | Approach | R-squared | MSE | MAE |
# | -------- | --------- | --- | --- |
# | RF | 0.56 +- 0.07 | 47.04 +- 9.07 | 5.48 +- 0.59 |
# | GPR | 0.53 +- 0.17 | 49.73 +- 17.02 | 5.67 +- 0.94 |
# | ICL_finetuned | 0.63 +- 0.17 | 39.28 +- 16.16 | 4.72 +- 0.72 |
# | ICL | 0.31 +- 0.25 | 70.65 +- 21.41 | 6.31 +- 1.03 |
