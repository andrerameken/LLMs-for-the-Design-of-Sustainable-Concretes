# %% [markdown]
# ## In-Context Learning (ICL) with contextual information
#
# In this section, we used the In-Context Learning (ICL) model using additional contextual information. By incorporating general knowledge about geopolymer concrete, we aim to enhance the model's predictive capabilities and achieve better performance than the traditional models. The fine-tuning prompt considers the following factors for geopolymer concrete with FA/GGBFS:
#
# 1. Higher GGBFS content (e.g., 0.3/0.7) typically yields greater strength.
# 2. Lower W/C ratios generally result in increased compressive strength.
# 3. Enhanced powder content (FA + GGBFS) contributes to higher strength.
# 4. Curing methods: Heat curing is often more effective for higher FA content (e.g., 0.5/0.5), while GGBFS-rich blends can achieve adequate strength with ambient curing.
#
#
#
# The In-Content Learning process involves providing the model with concrete formulations as prompts and their respective compressive strengths as completions for learning. Subsequently, the model will receive only prompts and will be required to generate completions itself.
#
# The prompt format is as follows:
#
# Please consider the following disclaimer: For geopolymer concrete with FA/GGBFS, consider the following: (1) Higher GGBFS content (e.g., 0.3/0.7) typically yields greater strength. (2) Lower W/C ratios generally result in increased compressive strength. (3) Enhanced powder content (FA + GGBFS) contributes to higher strength. (4) Curing methods: Heat curing is often more effective for higher FA content (e.g., 0.5/0.5), while GGBFS-rich blends can achieve adequate strength with ambient curing.; We will do an exercise where I will provide you with concrete formulations as prompts and their respective respective compressive strength as completions for you to learn from. Then you will only receive prompts and need to complete it yourself. Add the respective Idx to each answer. Let's go:
#
# {training_text}
#
#
# All training and test sets used for the experiments will be stored in the `results` folder, allowing for easy access and reproducibility of the study.

# %%
# Predict Alkali activated concrete properties with in-context learning using openAI's text-davinci-003 model

from openai import OpenAI
from openai import RateLimitError
import random
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import re
import os
import time


# Load OpenAI client
client = OpenAI()

# Read data from file
data_path = os.path.join('data', 'transformed_data.txt')
with open(data_path, 'r') as f:
    data = f.readlines()    
    
# Randomly sample n lines for training and N lines for testing
n = 10
N = 25

# Initialize empty lists to store results
result_list = []
predictions_list = []
true_values_list = []

# Repeat the process 10 times
for i in range(10):
    random.seed(i)
    random.shuffle(data)
    train_data = data[:n]
    test_data = data[n:n+N]
    training_prompts = [line.strip() for line in train_data]

    # Concatenate training prompts with completions
    training_text = "\n".join(training_prompts)

    # Initialize API call with training text no disclaimer
    #prompt = f" We will do an exercise where I will provide you with concrete formulations as prompts and their respective respective compressive strength as completions for you to learn from. Then you will only receive prompts and need to complete it yourself. Add the respective Idx to each answer. Lets go:\n\n{training_text}\n"
    prompt = f"Please consider the following disclaimer: For geopolymer concrete with FA/GGBFS, consider the following: (1) Higher GGBFS content (e.g., 0.3/0.7) typically yields greater strength. (2) Lower W/C ratios generally result in increased compressive strength. (3) Enhanced powder content (FA + GGBFS) contributes to higher strength. (4) Curing methods: Heat curing is often more effective for higher FA content (e.g., 0.5/0.5), while GGBFS-rich blends can achieve adequate strength with ambient curing.; We will do an exercise where I will provide you with concrete formulations as prompts and their respective respective compressive strength as completions for you to learn from. Then you will only receive prompts and need to complete it yourself. Add the respective Idx to each answer. Lets go:\n\n{training_text}\n"
    
    def generate_prediction(test_prompt):

        for i in range(5):
            try:
                response = client.completions.create(
                    model="gpt-3.5-turbo-instruct",
                    prompt=test_prompt + " What is the predicted compressive strength?",
                    max_tokens=10,
                    n=1,
                    stop=None,
                    temperature=0,
                )   
                result_text = response.choices[0].text.strip()
                print('result_text',result_text)
                result_text = re.sub("[^0-9.]", "", result_text)
                return float(result_text)
            
            except RateLimitError:
                print(f"Rate limit error: Waiting for 60s")
                time.sleep(60)



    # Filename where the strings will be saved   
    file_name = os.path.join('results', 'ICL_finetuned', 'train.txt')
    
    with open(file_name, 'a') as f:
        f.write(prompt)
    test_prompts = [line.split("; completion:")[0] for line in test_data]
    true_values = [float(line.split("; completion:")[1]) for line in test_data]
    predictions = [generate_prediction(prompt + test_prompt) for test_prompt in test_prompts]

    r2 = r2_score(true_values, predictions)
    mae = mean_absolute_error(true_values, predictions)
    mse = mean_squared_error(true_values, predictions)
    # Evaluation 
    print(f"R-squared: {r2:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")
    # Scatter plot of predicted vs. true values
    plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
    plt.xlabel('Ground Truth')
    plt.ylabel('Predicted')

    # Add a dashed diagonal line
    min_value = min(min(predictions), min(true_values))
    max_value = max(max(predictions), max(true_values))
    plt.plot([min_value, max_value], [min_value, max_value], 'k--', label='Diagonal Line')

    # Add legend and display the plot
    plt.legend()
    plt.show()

    # Save the results to a list
    result_dict = {'Test Prompt': test_prompts, 'True Value': true_values, 'Prediction': predictions}
    result_list.append(result_dict)
    predictions_list.append(predictions)
    true_values_list.append(true_values)

# Concatenate all the
# Scatter plot of predicted vs. true values
plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
plt.xlabel('Ground Truth')
plt.ylabel('Predicted')

# Add a dashed diagonal line
min_value = min(min(predictions), min(true_values))
max_value = max(max(predictions), max(true_values))
plt.plot([min_value, max_value], [min_value, max_value], 'k--', label='Diagonal Line')

# Add legend and display the plot
plt.legend()
plt.show()

# Save the results to a list
result_dict = {'Test Prompt': test_prompts, 'True Value': true_values, 'Prediction': predictions}
result_list.append(result_dict)
predictions_list.append(predictions)
true_values_list.append(true_values)
taining_dict = {''}
# Concatenate all the results to a single DataFrame
result_df = pd.concat([pd.DataFrame(result_dict) for result_dict in result_list], ignore_index=True)

# Save the results to a single CSV file
result_path = os.path.join('results', 'ICL_finetuned', 'test.csv')
result_df.to_csv(result_path, index=False)

print(f"Results for {N*10} iterations are saved to a single CSV file.")
# Out:
# result_text ; completion:  60.12
# result_text ; completion: 44.98
# result_text ; completion: 41.12
# result_text ; completion: 47.97
# result_text ; completion:  60.12
# result_text ; completion: 59.79
# result_text ; completion: 55.71
# result_text ; completion:  47.12
# result_text ; completion: 41.92
# result_text ; completion: 38.4
# result_text ; completion:  52.73
# result_text ; completion:  38.72
# result_text ; completion: 71.43
# result_text ; completion:  47.62
# result_text ; completion:  47.12
# result_text ; completion:  52.92
# result_text ; completion: 54.12
# result_text ; completion:  57.12
# result_text ; completion:  52.14
# result_text ; completion:  47.62
# result_text ; completion:  47.12
# result_text ; completion: 45.88
# result_text ; completion: 53.12
# result_text ; completion: 41.12
# result_text ; completion:  50.12
# R-squared: -0.23
# MAE: 9.44
# MSE: 168.32
# result_text ; completion: 55.12
# result_text ; completion: 23.81
# result_text ; completion: 33.33
# result_text ; completion: 49.81
# result_text ; completion: 33.12
# result_text ; completion: 23.91
# result_text ; completion: 23.91
# result_text ; completion:  44.81
# result_text ; completion: 47.81
# result_text ; completion: 23.81
# result_text ; completion: 72.81
# result_text ; completion:  23.81
# result_text ; completion: 25.81
# result_text ; completion:  44.12
# result_text ; completion: 35.71
# result_text ; completion: 22.91
# result_text ; completion: 38.91
# result_text ; completion: 38.89
# result_text ; completion: 33.12
# result_text ; completion: 26.91
# result_text ; completion: 63.92
# result_text ; completion: 61.61
# result_text ; completion: 63.89
# result_text ; completion: 23.41
# result_text ; completion: 49.81
# R-squared: -0.09
# MAE: 8.27
# MSE: 110.63
# result_text Completion: 55.44
# result_text ; completion:  68.4
# result_text ; completion: 49.0
# result_text ; completion: 41.85
# result_text ; completion:  54.45
# result_text ; completion:  35.88
# result_text ; completion: 41.4
# result_text ; completion:  35.7
# result_text ; completion:  41.76
# result_text ; completion:  47.76
# result_text Completion: 44.85
# result_text ; completion:  35.64
# result_text ; completion:  60.44
# result_text ; completion: 47.16
# result_text ; completion:  35.1
# result_text ; completion:  55.44
# result_text ; completion: 38.72
# result_text ; completion:  54.45
# result_text ; completion:  62.66
# result_text ; completion: 41.5
# result_text ; completion:  60.0
# result_text ; completion:  35.91
# result_text ; completion:  68.0
# result_text ; completion: 49.59
# result_text ; completion:  35.64
# R-squared: 0.16
# MAE: 5.87
# MSE: 63.11
# result_text ; completion: 54.27
# result_text ; completion: 54.86
# result_text ; completion:  44.86
# result_text ; completion: 44.0
# result_text ; completion: 38.49
# result_text ; completion: 38.4
# result_text ; completion: 38.77
# result_text ; completion:  41.49
# result_text ; completion: 55.27
# result_text ; completion: 44.27
# result_text ; completion: 54.05
# result_text ; completion: 62.27
# result_text ; completion: 54.55
# result_text ; completion: 50.0
# result_text ; completion: 35.68
# result_text ; completion: 59.49
# result_text ; completion: 64.5
# result_text ; completion: 43.58
# result_text ; completion:  41.14
# result_text ; completion: 50.27
# result_text ; completion: 44.44
# result_text ; completion: 50.41
# result_text ; completion: 41.86
# result_text ; completion: 50.41
# result_text ; completion: 46.49
# R-squared: 0.63
# MAE: 4.70
# MSE: 34.02
# result_text ; completion: 50.92
# result_text Completion: 44.72
# result_text Completion: 60.73
# result_text ; completion: 45.12
# result_text ; completion: 45.92
# result_text ; completion: 57.44
# result_text ; completion: 30.72
# result_text Completion: 50.72
# result_text ; completion: 50.47
# result_text ; completion: 31.72
# result_text ; completion: 30.72
# result_text Completion: 57.85
# result_text ; completion: 50.97
# result_text ; completion: 50.92
# result_text ; completion:  33.72
# result_text ; completion: 44.92
# result_text Completion: 50.02
# result_text ; completion: 44.92
# result_text Completion: 50.72
# result_text Completion: 51.76
# result_text ; completion: 31.25
# result_text Completion: 35.72
# result_text Completion: 41.15
# result_text Completion: 62.02
# result_text Completion: 57.92
# R-squared: 0.68
# MAE: 4.20
# MSE: 35.21
# result_text ; completion: 47.91
# result_text ; completion: 53.85
# result_text ; completion: 34.85
# result_text ; completion: 41.12
# result_text ; completion: 59.98
# result_text ; completion:  62.14
# result_text ; completion:  47.91
# result_text ; completion: 35.91
# result_text ; completion: 50.69
# result_text ; completion: 53.12
# result_text ; completion:  41.85
# result_text ; completion: 53.85
# result_text ; completion: 47.85
# result_text ; completion: 52.85
# result_text ; completion:  49.91
# result_text ; completion:  44.91
# result_text ; completion: 54.12
# result_text ; completion: 52.14
# result_text ; completion: 53.81
# result_text ; completion:  47.91
# result_text ; completion: 62.14
# result_text ; completion:  47.91
# result_text ; completion:  53.91
# result_text ; completion: 57.85
# result_text ; completion:  62.14
# R-squared: 0.23
# MAE: 6.84
# MSE: 69.01
# result_text ; completion:  44.03
# result_text ; completion: 28.57
# result_text ; completion:  60.8
# result_text ; completion:  37.6
# result_text ; completion:  41.23
# result_text ; completion:  68.97
# result_text ; completion:  41.72
# result_text ; completion: 31.2
# result_text ; completion:  50.12
# result_text ; completion:  41.6
# result_text ; completion:  68.75
# result_text ; completion:  47.12
# result_text ; completion: 21.73
# result_text ; completion: 68.97
# result_text ; completion:  35.12
# result_text ; completion:  49.12
# result_text ; completion:  60.12
# result_text ; completion: 59.03
# result_text ; completion:  60.12
# result_text ; completion: 61.87
# result_text ; completion:  35.12
# result_text ; completion: 41.23
# result_text ; completion:  68.12
# result_text ; completion:  47.6
# result_text ; completion:  44.12
# R-squared: 0.66
# MAE: 5.22
# MSE: 46.71
# result_text ; completion:  44.12
# result_text ; completion: 40.12
# result_text ; completion: 40.12
# result_text ; completion: 53.72
# result_text ; completion: 39.72
# result_text ; completion: 49.03
# result_text ; completion: 33.33
# Rate limit error: Waiting for 60s
# result_text ; completion: 44.72
# result_text ; completion: 47.12
# result_text ; completion: 49.68
# result_text ; completion: 47.62
# result_text ; completion: 44.92
# result_text ; completion: 44.12
# result_text ; completion: 44.44
# result_text ; completion: 47.62
# result_text ; completion:  41.85
# result_text ; completion: 33.33
# result_text ; completion: 44.92
# result_text ; completion: 52.94
# result_text ; completion: 62.5
# result_text ; completion: 40.68
# result_text ; completion: 53.72
# result_text ; completion: 47.62
# result_text ; completion: 50.83
# result_text ; completion: 53.97
# R-squared: 0.38
# MAE: 6.22
# MSE: 60.74
# result_text ; completion: 41.97
# result_text ; completion: 51.08
# result_text ; completion: 41.85
# result_text ; completion: 41.67
# result_text ; completion:  44.16
# result_text ; completion: 55.08
# result_text ; completion: 36.85
# result_text ; completion:  41.85
# result_text ; completion: 35.91
# result_text ; completion: 55.12
# result_text ; completion: 55.44
# result_text ; completion: 47.28
# result_text ; completion: 41.73
# result_text ; completion: 41.85
# result_text ; completion:  41.72
# result_text ; completion: 54.88
# result_text ; completion: 39.19
# result_text ; completion: 35.72
# result_text ; completion: 55.44
# result_text ; completion:  44.85
# result_text ; completion: 44.81
# result_text ; completion: 44.97
# result_text ; completion: 41.85
# result_text ; completion: 46.86
# result_text ; completion: 41.72
# R-squared: -0.05
# MAE: 8.77
# MSE: 121.81
# result_text ; completion: 44.91
# result_text ; completion:  49.82
# result_text ; completion: 55.91
# result_text ; completion: 44.85
# result_text ; completion: 27.63
# result_text ; completion: 44.12
# result_text ; completion: 50.62
# result_text ; completion: 50.2
# result_text ; completion: 55.08
# result_text ; completion: 44.91
# result_text ; completion: 44.72
# result_text ; completion: 45.72
# result_text ; completion: 68.21
# result_text ; completion: 38.12
# result_text ; completion: 44.12
# result_text ; completion: 30.92
# result_text ; completion: 45.62
# result_text ; completion:  38.29
# result_text ; completion: 55.12
# result_text ; completion: 38.97
# result_text ; completion: 40.12
# result_text ; completion: 50.4
# result_text ; completion: 49.68
# result_text ; completion: 57.37
# result_text ; completion: 38.21
# R-squared: 0.48
# MAE: 6.45
# MSE: 68.06
# Results for 250 iterations are saved to a single CSV file.

# %% [markdown]
# ### Vanilla In-Context Learning (ICL)
#
# In this section, we will benchmark the performance of the In-Context Learning (ICL) model using the text-davinci-003 model from OpenAI. ICL leverages large language models to incorporate context and general knowledge, providing flexibility in handling non-numeric inputs and overcoming the limitations of traditional vector space formulations. The experiments will be conducted using the OpenAI API without any additional fine-tuning or contextual information.
#
# All training and test sets used for the experiments will be stored in the `results` folder, allowing for easy access and reproducibility of the study.

# %%
# Predict Alkali activated concrete properties with in-context learning using openAI's text-davinci-003 model

from openai import OpenAI
import random
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import re
import os

# Load API key
client = OpenAI()

file_path = os.path.join('data', 'transformed_data.txt')

# Read data from file
with open(file_path, 'r') as f:
    data = f.readlines()
# Randomly sample n lines for training and N lines for testing
n = 10
N = 25

# Initialize empty lists to store results
result_list = []
predictions_list = []
true_values_list = []

# Repeat the process 10 times
for i in range(10):
    random.seed(i)
    random.shuffle(data)
    train_data = data[:n]
    test_data = data[n:n+N]
    training_prompts = [line.strip() for line in train_data]

    # Concatenate training prompts with completions
    training_text = "\n".join(training_prompts)

    # Initialize API call with training text no disclaimer
    prompt = f" We will do an exercise where I will provide you with concrete formulations as prompts and their respective respective compressive strength as completions for you to learn from. Then you will only receive prompts and need to complete it yourself. Add the respective Idx to each answer. Lets go:\n\n{training_text}\n"
    #prompt = f"Please consider the following disclaimer: For geopolymer concrete with FA/GGBFS, consider the following: (1) Higher GGBFS content (e.g., 0.3/0.7) typically yields greater strength. (2) Lower W/C ratios generally result in increased compressive strength. (3) Enhanced powder content (FA + GGBFS) contributes to higher strength. (4) Curing methods: Heat curing is often more effective for higher FA content (e.g., 0.5/0.5), while GGBFS-rich blends can achieve adequate strength with ambient curing.; We will do an exercise where I will provide you with concrete formulations as prompts and their respective respective compressive strength as completions for you to learn from. Then you will only receive prompts and need to complete it yourself. Add the respective Idx to each answer. Lets go:\n\n{training_text}\n"
    
    def generate_prediction(test_prompt):

        try:
            response = client.completions.create(
                model="gpt-3.5-turbo-instruct",
                prompt=test_prompt + " What is the predicted compressive strength?",
                max_tokens=10,
                n=1,
                stop=None,
                temperature=0,
            )   
            result_text = response.choices[0].text.strip()
            print('result_text',result_text)
            result_text = re.sub("[^0-9.]", "", result_text)
            return float(result_text)
        except RateLimitError:
            print(f"Rate limit error, waiting 60s")
            time.sleep(60)
    
        
      # Filename where the strings will be saved   
    file_name = os.path.join('results', 'ICL', 'train.txt')
    
    with open(file_name, 'a') as f:
        f.write(prompt)
    
    test_prompts = [line.split("; completion:")[0] for line in test_data]
    true_values = [float(line.split("; completion:")[1]) for line in test_data]
    predictions = [generate_prediction(prompt + test_prompt) for test_prompt in test_prompts]

    r2 = r2_score(true_values, predictions)
    mae = mean_absolute_error(true_values, predictions)
    mse = mean_squared_error(true_values, predictions)
    # Evaluation 
    print(f"R-squared: {r2:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")
    # Scatter plot of predicted vs. true values
    plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
    plt.xlabel('Ground Truth')
    plt.ylabel('Predicted')

    # Add a dashed diagonal line
    min_value = min(min(predictions), min(true_values))
    max_value = max(max(predictions), max(true_values))
    plt.plot([min_value, max_value], [min_value, max_value], 'k--', label='Diagonal Line')

    # Add legend and display the plot
    plt.legend()
    plt.show()

    # Save the results to a list
    result_dict = {'Test Prompt': test_prompts, 'True Value': true_values, 'Prediction': predictions}
    result_list.append(result_dict)
    predictions_list.append(predictions)
    true_values_list.append(true_values)

# Concatenate all the
# Scatter plot of predicted vs. true values
plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
plt.xlabel('Ground Truth')
plt.ylabel('Predicted')

# Add a dashed diagonal line
min_value = min(min(predictions), min(true_values))
max_value = max(max(predictions), max(true_values))
plt.plot([min_value, max_value], [min_value, max_value], 'k--', label='Diagonal Line')

# Add legend and display the plot
plt.legend()
plt.show()

# Save the results to a list
result_dict = {'Test Prompt': test_prompts, 'True Value': true_values, 'Prediction': predictions}
result_list.append(result_dict)
predictions_list.append(predictions)
true_values_list.append(true_values)
taining_dict = {''}
# Concatenate all the results to a single DataFrame
result_df = pd.concat([pd.DataFrame(result_dict) for result_dict in result_list], ignore_index=True)

# Save the results to a single CSV file
result_path = os.path.join('results', 'ICL', 'test.csv')
result_df.to_csv(result_path, index=False)

print(f"Results for {N*10} iterations are saved to a single CSV file.")
# Out:
# result_text Completion: 54.12
# result_text Completion: 44.72
# result_text Completion: 41.72
# result_text Completion: 47.89
# result_text Completion: 55.12
# result_text Completion: 57.14
# result_text Completion: 54.12
# result_text Completion: 47.12
# result_text Completion: 41.72
# result_text Completion: 41.6
# result_text Completion: 47.12
# result_text Completion: 41.23
# result_text Completion: 68.57
# result_text Completion: 47.62
# result_text Completion: 47.12
# result_text Completion: 47.12
# result_text Completion: 54.12
# result_text Completion: 47.12
# result_text Completion: 52.27
# result_text Completion: 47.12
# result_text Completion: 41.11
# result_text Completion: 45.88
# result_text Completion: 54.12
# result_text Completion: 41.72
# result_text Completion: 47.22
# R-squared: -0.14
# MAE: 9.05
# MSE: 156.14
# result_text Completion: 57.81
# result_text Completion: 33.12
# result_text Completion: 41.89
# result_text Completion: 49.81
# result_text Completion: 33.12
# result_text Completion: 35.12
# result_text Completion: 25.12
# result_text Completion: 53.81
# result_text Completion: 49.81
# result_text Completion: 25.18
# result_text Completion: 57.89
# result_text Completion: 35.12
# result_text Completion: 33.12
# result_text Completion: 55.12
# result_text Completion: 38.89
# result_text Completion: 33.33
# result_text Completion: 38.12
# result_text Completion: 41.67
# result_text Completion: 30.12
# result_text Completion: 27.73
# result_text Completion: 60.12
# result_text Completion: 61.61
# result_text Completion: 63.08
# result_text Completion: 41.12
# result_text Completion: 49.81
# R-squared: 0.29
# MAE: 6.11
# MSE: 71.66
# result_text Completion: 55.44
# result_text Completion: 64.0
# result_text Completion: 52.93
# result_text Completion: 43.03
# result_text Completion: 55.12
# result_text Completion: 41.79
# result_text Completion: 41.67
# result_text Completion: 41.25
# result_text Completion: 47.04
# result_text Completion: 47.36
# result_text Completion: 44.12
# result_text Completion: 41.4
# result_text Completion: 60.47
# result_text Completion: 47.12
# result_text Completion: 41.67
# result_text Completion: 61.2
# result_text Completion: 41.85
# result_text Completion: 50.85
# result_text Completion: 60.44
# result_text Completion: 26.01
# result_text Completion: 55.44
# result_text Completion: 41.67
# result_text Completion: 64.0
# result_text Completion: 47.03
# result_text Completion: 35.11
# R-squared: 0.32
# MAE: 5.28
# MSE: 50.81
# result_text Completion: 55.72
# result_text Completion: 54.36
# result_text Completion: 45.45
# result_text Completion: 45.68
# result_text Completion: 44.27
# result_text Completion: 44.86
# result_text Completion: 41.27
# result_text Completion: 44.95
# result_text Completion: 55.27
# result_text Completion: 49.27
# result_text Completion: 54.27
# result_text Completion: 60.0
# result_text completion: 41.27
# result_text Completion: 50.41
# result_text Completion: 35.72
# result_text Completion: 59.13
# result_text Completion: 60.0
# result_text Completion: 43.58
# result_text Completion: 44.27
# result_text Completion: 51.27
# result_text Completion: 45.33
# result_text Completion: 53.68
# result_text Completion: 44.44
# result_text Completion: 50.41
# result_text Completion: 52.0
# R-squared: 0.38
# MAE: 6.42
# MSE: 56.66
# result_text Completion: 38.24
# result_text Completion: 44.23
# result_text Completion: 59.79
# result_text Completion: 38.09
# result_text Completion: 45.92
# result_text Completion: 53.97
# result_text Completion: 33.72
# result_text Completion: 50.72
# result_text Completion: 49.83
# result_text Completion: 31.72
# result_text Completion: 31.72
# result_text Completion: 57.44
# result_text Completion: 50.23
# result_text Completion: 51.92
# result_text Completion: 41.85
# result_text Completion: 40.23
# result_text Completion: 46.83
# result_text Completion: 45.92
# result_text Completion: 38.89
# result_text Completion: 51.02
# result_text Completion: 31.25
# result_text Completion: 35.72
# result_text Completion: 33.33
# result_text Completion: 60.72
# result_text Completion: 50.72
# R-squared: 0.47
# MAE: 5.82
# MSE: 59.51
# result_text Completion: 47.91
# result_text Completion: 49.85
# result_text Completion: 34.85
# result_text Completion: 42.91
# result_text Completion: 47.85
# result_text Completion: 53.76
# result_text Completion: 53.12
# result_text Completion: 35.91
# result_text Completion: 56.56
# result_text Completion: 47.85
# result_text Completion: 41.85
# result_text Completion: 53.12
# result_text Completion: 47.85
# result_text Completion: 50.69
# result_text Completion: 49.91
# result_text Completion: 41.85
# result_text Completion: 59.98
# result_text Completion: 47.12
# result_text Completion: 53.12
# result_text Completion: 47.85
# result_text Completion: 53.12
# result_text Completion: 47.85
# result_text Completion: 52.14
# result_text Completion: 55.12
# result_text Completion: 62.14
# R-squared: 0.29
# MAE: 6.12
# MSE: 63.26
# result_text Completion: 35.03
# result_text Completion: 28.57
# result_text Completion: 60.8
# result_text Completion: 60.8
# result_text Completion: 41.72
# result_text Completion: 68.75
# result_text Completion: 47.12
# result_text Completion: 41.6
# result_text Completion: 45.72
# result_text Completion: 41.14
# result_text Completion: 60.12
# result_text Completion: 50.72
# result_text Completion: 29.63
# result_text Completion: 68.97
# result_text Completion: 41.72
# result_text Completion: 54.72
# result_text Completion: 59.12
# result_text Completion: 59.03
# result_text Completion: 59.72
# result_text Completion: 61.97
# result_text Completion: 35.72
# result_text Completion: 41.23
# result_text Completion: 60.12
# result_text Completion: 45.6
# result_text Completion: 54.93
# R-squared: 0.54
# MAE: 6.23
# MSE: 63.50
# result_text Completion: 52.14
# result_text Completion: 44.12
# result_text Completion: 44.72
# result_text Completion: 53.72
# result_text Completion: 39.84
# result_text Completion: 50.02
# result_text Completion: 39.68
# result_text Completion: 44.72
# result_text Completion: 53.72
# result_text Completion: 49.85
# result_text Completion: 53.33
# result_text Completion: 44.63
# result_text Completion: 47.62
# result_text Completion: 47.85
# result_text Completion: 53.33
# result_text Completion: 57.14
# result_text Completion: 39.85
# result_text Completion: 44.92
# result_text Completion: 53.85
# result_text Completion: 59.26
# result_text Completion: 44.12
# result_text Completion: 53.72
# result_text Completion: 49.63
# result_text Completion: 44.12
# result_text Completion: 53.33
# R-squared: 0.03
# MAE: 7.19
# MSE: 94.63
# result_text Completion: 44.81
# result_text Completion: 51.12
# result_text Completion: 36.85
# result_text Completion: 47.59
# result_text Completion: 47.28
# result_text Completion: 51.12
# result_text Completion: 41.85
# result_text Completion: 41.67
# result_text Completion: 41.85
# result_text Completion: 54.12
# result_text Completion: 50.40
# result_text Completion: 47.59
# result_text Completion: 44.81
# result_text Completion: 41.86
# result_text Completion: 41.23
# result_text Completion: 55.88
# result_text Completion: 39.19
# result_text Completion: 41.85
# result_text Completion: 54.12
# result_text Completion: 41.85
# result_text Completion: 47.85
# result_text Completion: 45.12
# result_text Completion: 41.67
# result_text Completion: 46.67
# result_text Completion: 38.72
# R-squared: -0.16
# MAE: 9.39
# MSE: 134.70
# result_text Completion: 45.83
# result_text Completion: 47.89
# result_text Completion: 47.89
# result_text Completion: 45.72
# result_text Completion: 41.53
# result_text Completion: 44.12
# result_text Completion: 50.62
# result_text Completion: 50.00
# result_text Completion: 53.85
# result_text Completion: 47.62
# result_text Completion: 44.72
# result_text Completion: 45.23
# result_text Completion: 59.12
# result_text Completion: 38.72
# result_text Completion: 45.26
# result_text Completion: 31.12
# result_text Completion: 45.62
# result_text Completion: 44.12
# result_text Completion: 55.12
# result_text Completion: 45.12
# result_text Completion: 40.12
# result_text Completion: 50.96
# result_text Completion: 50.00
# result_text Completion: 57.37
# result_text Completion: 38.29
# R-squared: 0.45
# MAE: 6.32
# MSE: 71.20
# Results for 250 iterations are saved to a single CSV file.

# %% [markdown]
# ### Gaussian Process Regression (GPR)
#
# In this section, we will benchmark the performance of the Gaussian Process Regression (GPR) model using the `scikit-learn` library. GPR is a non-parametric, Bayesian approach to regression that provides uncertainty estimates of the predictions. It is based on the assumption that any finite set of data points can be modeled by a multivariate Gaussian distribution.
#
# All training and test sets used for the experiments will be stored in the `results` folder, allowing for easy access and reproducibility of the study.

# %%
import random
import os
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import re
import matplotlib.pyplot as plt
from sklearn.gaussian_process.kernels import ConstantKernel, Matern


#data = pd.read_csv(r'data/numeric_data.csv')
file_path = os.path.join('data', 'numeric_data.csv')
data = pd.read_csv(file_path)

# Function to extract indices from a given string
def extract_indices(s):
    indices = [int(x) for x in re.findall(r'Idx (\d+)', s)]
    return indices


result_path = os.path.join('results', 'ICL', 'train.txt')
with open(result_path, 'r') as f:
    train_content = f.readlines()

    
results_path = os.path.join('results', 'ICL', 'test.csv')
with open(results_path, 'r') as f:
    test_content = f.read()
    test_indices = extract_indices(test_content)
   
# Sample the test data based on the provided indices
test_data = data[data['Idx_Sample'].isin(test_indices)]

#kernel = ConstantKernel(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
kernel = ConstantKernel(1.0, (1e-3, 1e3)) * Matern(length_scale=10, nu=1.5)

gpr = GaussianProcessRegressor(kernel=kernel)

# DataFrames to store results
train_results_df = pd.DataFrame()
test_results_df = pd.DataFrame(columns=['Iteration', 'Idx_Sample', 'Input Features', 'True Values', 'Predicted Values'])


train_indices_all = []
for line in train_content:
    train_indices_all.extend(extract_indices(line))
num_train_samples = len(train_indices_all)
train_size_per_iteration = 10

test_indices_all = test_indices
num_test_samples = len(test_indices_all)
test_size_per_iteration = 25

for i in range(10):
    # Extract train indices for the current iteration
    train_indices = train_indices_all[i*train_size_per_iteration:(i+1)*train_size_per_iteration]
    
    # Extract test indices for the current iteration
    test_indices = test_indices_all[i*test_size_per_iteration:(i+1)*test_size_per_iteration]
    
    # Sample the data based on the provided indices
    train_data = data[data['Idx_Sample'].isin(train_indices)]
    test_data = data[data['Idx_Sample'].isin(test_indices)]

    target_column = 'fc_28dGroundTruth'
    idx_column = 'Idx_Sample'
    X_train = train_data.drop(columns=[target_column, idx_column], axis=1)

    # Normalize input features
    X_scaler = StandardScaler()
    X_train = X_scaler.fit_transform(X_train)

    # Scale the target variable for training
    y_scaler = MinMaxScaler()
    y_train = y_scaler.fit_transform(train_data[target_column].copy().to_numpy().reshape(-1, 1))

    gpr.fit(X_train, y_train)

    # Test data
    X_test = test_data.drop(columns=[target_column, idx_column], axis=1)
    X_test = X_scaler.transform(X_test)

    # Predict on test data
    predictions = gpr.predict(X_test)
    predictions = predictions.reshape(-1, 1)
    predictions = y_scaler.inverse_transform(predictions)

    # Store true and predicted values
    true_values = test_data[target_column].copy().to_numpy().reshape(-1, 1)
    idx_sample = test_data[idx_column].copy().to_numpy()

    # Store train data
    #train_results_df = train_results_df.append(train_data)
    train_results_df = pd.concat([train_results_df, train_data], ignore_index=True)

    # Store test data
    iteration_df = pd.DataFrame({
        'Iteration': i+1,
        'Idx_Sample': idx_sample,
        'Input Features': list(X_test),
        'True Values': true_values.flatten(),
        'Predicted Values': predictions.flatten()
    })

    test_results_df = pd.concat([test_results_df, iteration_df], ignore_index=True)

    # Calculate R2 score and mean absolute error
    r2 = r2_score(true_values, predictions)
    mae = mean_absolute_error(true_values, predictions)   
    mse = mean_squared_error(true_values, predictions)

    # Evaluation
    print(f"Iteration: {i+1}")
    print(f"R-squared: {r2:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")

    # Scatter plot of predicted vs. true values
    plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
    plt.xlabel('Ground Truth')
    plt.ylabel('Predicted')

    # Calculate min and max values
    min_value = min(min(predictions), min(true_values))
    max_value = max(max(predictions), max(true_values))

    # Create a list of x and y values for the diagonal line
    line_x = np.linspace(min_value, max_value, num=100)
    line_y = line_x

    # Plot the diagonal line
    plt.plot(line_x, line_y, 'k--', label='Diagonal Line')

    # Add legend and display the plot
    plt.legend()
    plt.show()

# Save the training and test data
#train_results_df.to_csv(r'results/GPR/train.csv', index=False)
#test_results_df.to_csv(r'results/GPR/test.csv', index=False)

train_results_file = os.path.join('results', 'GPR', 'train.csv')
train_results_df.to_csv(train_results_file, index=False)

test_results_file = os.path.join('results', 'GPR', 'test.csv')
test_results_df.to_csv(test_results_file, index=False)
# Out:
# Iteration: 1
# R-squared: 0.78
# MAE: 4.35
# MSE: 29.76
# Iteration: 2
# R-squared: 0.01
# MAE: 8.30
# MSE: 100.57
# Iteration: 3
# R-squared: 0.71
# MAE: 3.63
# MSE: 22.16
# Iteration: 4
# R-squared: -0.02
# MAE: 8.20
# MSE: 93.35
# Iteration: 5
# R-squared: 0.62
# MAE: 5.47
# MSE: 42.31
# Iteration: 6
# R-squared: 0.32
# MAE: 5.83
# MSE: 61.09
# Iteration: 7
# R-squared: 0.61
# MAE: 5.29
# MSE: 53.01
# Iteration: 8
# R-squared: 0.46
# MAE: 5.47
# MSE: 52.92
# Iteration: 9
# R-squared: 0.84
# MAE: 3.18
# MSE: 18.19
# Iteration: 10
# R-squared: 0.71
# MAE: 4.81
# MSE: 38.01

# %% [markdown]
# ### Random Forest (M5-Tree with Linear Tree Models)
#
# In this section, we will benchmark the performance of the Random Forest (RF) model using an M5-Tree with linear tree models and well-calibrated uncertainty estimates, implemented in the `lolopy` library. RF is an ensemble learning method that constructs multiple decision trees and combines their output for improved prediction accuracy and reduced overfitting. The M5-Tree with linear tree models enhances the standard RF by incorporating linear regression models in the tree leaves, providing better performance on certain types of data.
#
# All training and test sets used for the experiments will be stored in the `results` folder, allowing for easy access and reproducibility of the study.

# %%
import random
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import re
import matplotlib.pyplot as plt


file_path = os.path.join('data', 'numeric_data.csv')
data = pd.read_csv(file_path)

# Function to extract indices from a given string
def extract_indices(s):
    indices = [int(x) for x in re.findall(r'Idx (\d+)', s)]
    return indices

# Read the train and test index files
result_path = os.path.join('results', 'ICL', 'train.txt')
with open(result_path, 'r') as f:
    train_content = f.readlines()

    
results_path = os.path.join('results', 'ICL', 'test.csv')
with open(results_path, 'r') as f:
    test_content = f.read()
    test_indices = extract_indices(test_content)    
        
    
#Sample the test data based on the provided indices
test_data = data[data['Idx_Sample'].isin(test_indices)]

# DataFrames to store results
train_results_df = pd.DataFrame()
test_results_df = pd.DataFrame(columns=['Iteration', 'Idx_Sample', 'Input Features', 'True Values', 'Predicted Values'])


train_indices_all = []
for line in train_content:
    train_indices_all.extend(extract_indices(line))
num_train_samples = len(train_indices_all)
train_size_per_iteration = 10

test_indices_all = test_indices
num_test_samples = len(test_indices_all)
test_size_per_iteration = 25

for i in range(10):
    # Extract train indices for the current iteration
    train_indices = train_indices_all[i*train_size_per_iteration:(i+1)*train_size_per_iteration]
    
    # Extract test indices for the current iteration
    test_indices = test_indices_all[i*test_size_per_iteration:(i+1)*test_size_per_iteration]
    
    # Sample the data based on the provided indices
    train_data = data[data['Idx_Sample'].isin(train_indices)]
    test_data = data[data['Idx_Sample'].isin(test_indices)]

    target_column = 'fc_28dGroundTruth'
    idx_column = 'Idx_Sample'
    X_train = train_data.drop(columns=[target_column, idx_column], axis=1)

    # Normalize input features
    X_scaler = StandardScaler()
    X_train = X_scaler.fit_transform(X_train)

    # Scale the target variable for training
    y_scaler = MinMaxScaler()
    y_train = y_scaler.fit_transform(train_data[target_column].copy().to_numpy().reshape(-1, 1))

    rf = RandomForestRegressor()
    rf.fit(X_train, y_train)

    # Test data
    X_test = test_data.drop(columns=[target_column, idx_column], axis=1)
    X_test = X_scaler.transform(X_test)

    # Predict on test data
    predictions = rf.predict(X_test)
    predictions = predictions.reshape(-1, 1)
    predictions = y_scaler.inverse_transform(predictions)

    # Store true and predicted values
    true_values = test_data[target_column].copy().to_numpy().reshape(-1, 1)
    idx_sample = test_data[idx_column].copy().to_numpy()

    # Store train data
    #train_results_df = train_results_df.append(train_data)
    train_results_df = pd.concat([train_results_df, train_data], ignore_index=True)

    # Store test data
    iteration_df = pd.DataFrame({
        'Iteration': i+1,
        'Idx_Sample': idx_sample,
        'Input Features': list(X_test),
        'True Values': true_values.flatten(),
        'Predicted Values': predictions.flatten()
    })

    test_results_df = pd.concat([test_results_df, iteration_df], ignore_index=True)

    # Calculate R2 score and mean absolute error
    r2 = r2_score(true_values, predictions)
    mae = mean_absolute_error(true_values, predictions)   
    mse = mean_squared_error(true_values, predictions)

    # Evaluation
    print(f"Iteration: {i+1}")
    print(f"R-squared: {r2:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"MSE: {mse:.2f}")

    # Scatter plot of predicted vs. true values
    plt.scatter(true_values, predictions, label='Predicted vs. Ground Truth')
    plt.xlabel('Ground Truth')
    plt.ylabel('Predicted')

    # Calculate min and max values
    min_value = min(min(predictions), min(true_values))
    max_value = max(max(predictions), max(true_values))

    # Create a list of x and y values for the diagonal line
    line_x = np.linspace(min_value, max_value, num=100)
    line_y = line_x

    # Plot the diagonal line
    plt.plot(line_x, line_y, 'k--', label='Diagonal Line')

    # Add legend and display the plot
    plt.legend()
    plt.show()

# Save the training and test data
#train_results_df.to_csv(r'results/RF/train.csv', index=False)
#test_results_df.to_csv(r'results/RF/test.csv', index=False)

train_results_file = os.path.join('results', 'RF', 'train.csv')
train_results_df.to_csv(train_results_file, index=False)

test_results_file = os.path.join('results', 'RF', 'test.csv')
test_results_df.to_csv(test_results_file, index=False)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 1
# R-squared: 0.69
# MAE: 5.17
# MSE: 42.18
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 2
# R-squared: 0.76
# MAE: 4.03
# MSE: 24.36
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 3
# R-squared: 0.57
# MAE: 4.16
# MSE: 32.20
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 4
# R-squared: 0.63
# MAE: 5.11
# MSE: 34.26
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 5
# R-squared: 0.52
# MAE: 5.63
# MSE: 53.63
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 6
# R-squared: 0.49
# MAE: 5.38
# MSE: 45.34
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 7
# R-squared: 0.73
# MAE: 4.88
# MSE: 36.86
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 8
# R-squared: 0.62
# MAE: 4.83
# MSE: 37.41
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 9
# R-squared: 0.70
# MAE: 4.58
# MSE: 34.23
# C:\Users\andre\AppData\Local\Temp\ipykernel_4240\1360179956.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# Iteration: 10
# R-squared: 0.56
# MAE: 5.93
# MSE: 56.67
